# %% [markdown]
# # Automação Web e Busca de Informações com Python
#
# -entar na internet
# -Entrar wprld bank
# -Selecionar todos os países atravez de csv
# -Para cada indicador escrever na barra, recolher info e adicionar as lista de indicadores.
# -Fazer tratamento de dados
# -Exportar para csv

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from datetime import datetime
import csv
import requests
import lxml.html as lh

TED_link = "https://data.worldbank.org/indicator/SE.TER.ENRR"
RD_link = "https://data.worldbank.org/indicator/GB.XPD.RSDV.GD.ZS"
WPART_link ="https://data.worldbank.org/indicator/SL.TLF.CACT.FE.ZS"
UN_link = "https://data.worldbank.org/indicator/SL.UEM.TOTL.ZS"
FDI_link = "https://data.worldbank.org/indicator/BX.KLT.DINV.CD.WD"
GDP_link = "https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD"
GNI_link = "https://data.worldbank.org/indicator/SI.POV.GINI"
DIR_link = "https://data.worldbank.org/indicator/FR.INR.DPST"
TBLC_link = "https://data.worldbank.org/indicator/NE.RSB.GNFS.ZS"
OPN_link = "https://data.worldbank.org/indicator/NE.TRD.GNFS.ZS"

#create lists
country_list_TED=[]
year_list_TED=[]
value_list_TED=[]
year_list_RD=[]
value_list_RD=[]
year_list_WPART=[]
value_list_WPART=[]
year_list_UN=[]
value_list_UN=[]
year_list_FDI=[]
value_list_FDI=[]
year_list_GDP=[]
value_list_GDP=[]
year_list_GNI=[]
value_list_GNI=[]
year_list_DIR=[]
value_list_DIR=[]
year_list_TBLC=[]
value_list_TBLC=[]
year_list_OPN=[]
value_list_OPN=[]

#get countries from csv
file = open("world_bank_countries.csv", "r")
csv_reader = csv.reader(file)
next(csv_reader)

wb_country_list = []
for row in csv_reader:
    wb_country_list.append(row)


#entrar no site
navegador = webdriver.Chrome()
navegador.get(TED_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1):
    country = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(1)+"]").text
    country_list_TED.append(country)

    
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_TED.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_TED.append(value)  
    print("done")
    
######################################################################################################
########################################################################################################
#entrar no site
navegador.get(RD_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1): 
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_RD.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_RD.append(value)      
    print("done")
    

######################################################################################################
########################################################################################################
#entrar no site
navegador.get(WPART_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1):    
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_WPART.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_WPART.append(value)    
    print("done")
    

######################################################################################################
########################################################################################################
#entrar no site
navegador.get(UN_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1):    
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_UN.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_UN.append(value)      
    print("done")
    
    
######################################################################################################
########################################################################################################
#entrar no site
navegador.get(FDI_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1): 
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_FDI.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_FDI.append(value)    
    print("done")
    
    
######################################################################################################
########################################################################################################
#entrar no site
navegador.get(GDP_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1):    
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_GDP.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_GDP.append(value) 
    print("done")
    
    
    
######################################################################################################
########################################################################################################
#entrar no site
navegador.get(GNI_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1):    
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_GNI.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_GNI.append(value)      
    print("done")
    
    
    
######################################################################################################
########################################################################################################
#entrar no site
navegador.get(DIR_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1):
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_DIR.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_DIR.append(value) 
    print("done")
    
    

######################################################################################################
########################################################################################################
#entrar no site
navegador.get(TBLC_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1):    
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_TBLC.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_TBLC.append(value) 
    print("done")
    
    
######################################################################################################
########################################################################################################
#entrar no site
navegador.get(OPN_link)
navegador.find_element_by_xpath('//*[@id="selector"]').click()

#escrever países na box
for index, element in enumerate (wb_country_list):
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(element)
    time.sleep(2)
    navegador.find_element_by_xpath('//*[@id="selector"]').send_keys(Keys.ENTER)
    
#receber info da tabela
#count number of rows
rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))

for r in range(1,rows+1):   
    year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
    year_list_OPN.append(year)
    
    value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
    value_list_OPN.append(value)  
    print("done")
    
    
navegador.quit()
print("Done")
# Out:
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# done
# ...

# %%
import pandas as pd

lista_zip = list(zip(country_list_TED,year_list_TED, value_list_TED,year_list_RD,value_list_RD,year_list_UN,value_list_UN,year_list_FDI,value_list_FDI,year_list_GDP,value_list_GDP,year_list_GNI,value_list_GNI,year_list_DIR,value_list_DIR,year_list_TBLC,value_list_TBLC,year_list_OPN,value_list_OPN))

tabela = pd.DataFrame((lista_zip), columns=['country_list_TED','year_list_TED', 'value_list_TED','year_list_RD','value_list_RD','year_list_UN','value_list_UN','year_list_FDI','value_list_FDI','year_list_GDP','value_list_GDP','year_list_GNI','value_list_GNI','year_list_DIR','value_list_DIR','year_list_TBLC','value_list_TBLC','year_list_OPN','value_list_OPN'])
display(tabela)
# Out:
#         country_list_TED year_list_TED value_list_TED year_list_RD  \
# 0              Argentina          2017             90         2017
# 1                 Brazil          2011             43         2017
# 2             Cabo Verde          2018             24         2011
# 3               Colombia          2018             55         2018
# 4       Egypt, Arab Rep.          2017             35         2018
# 5                 France          2018             68         2018
# 6                Germany          2018             70         2018
# 7                  Ghana          2019             17         2010
# 8   Hong Kong SAR, China          2019             81         2018
# 9                  India          2019             29         2018
# 10             Indonesia          2018             36         2018
# 11                  Iraq          2005             16         2018
# 12                 Japan                                      2018
# ...

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from datetime import datetime
import csv
import requests
import lxml.html as lh
navegador = webdriver.Chrome()

TED_link = "https://data.worldbank.org/indicator/SE.TER.ENRR?locations=BR-SI-DE-PT"
RD_link = "https://data.worldbank.org/indicator/GB.XPD.RSDV.GD.ZS?locations=BR-SI-DE-PT"
WPART_link ="https://data.worldbank.org/indicator/SL.TLF.CACT.FE.ZS?locations=BR-SI-DE-PT"
UN_link = "https://data.worldbank.org/indicator/SL.UEM.TOTL.ZS?locations=BR-SI-DE-PT"
FDI_link = "https://data.worldbank.org/indicator/BX.KLT.DINV.CD.WD?locations=BR-SI-DE-PT"
GDP_link = "https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD?locations=BR-SI-DE-PT"
GNI_link = "https://data.worldbank.org/indicator/SI.POV.GINI?locations=BR-SI-DE-PT"
DIR_link = "https://data.worldbank.org/indicator/FR.INR.DPST?locations=BR-SI-DE-PT"
TBLC_link = "https://data.worldbank.org/indicator/NE.RSB.GNFS.ZS?locations=BR-SI-DE-PT"
OPN_link = "https://data.worldbank.org/indicator/NE.TRD.GNFS.ZS?locations=BR-SI-DE-PT"

link_list = [TED_link, RD_link, WPART_link, UN_link, FDI_link, GDP_link, GNI_link, DIR_link, TBLC_link, OPN_link]
#print(link_list)

for link in link_list:
    navegador.get(link)
    rows = len(navegador.find_elements_by_xpath('//*[@id="main"]/div/span/article[1]/div/div/section/div/div[2]/div'))
    cols = len(navegador.find_elements_by_xpath('/html/body/div[1]/div/div/div/div[3]/div/span/article[1]/div/div/section/div/div[1]/div'))
    
    for r in range(1,rows+1):
        country = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(1)+"]").text
        country_list.append(country)

    
        year = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(2)+"]").text
        year_list.append(year)
    
        value = navegador.find_element_by_xpath("//*[@id='main']/div/span/article[1]/div/div/section/div/div[2]/div["+str(r)+"]/div["+str(3)+"]").text
        value_list.append(value)     
        
        #print(value)
        
import pandas as pd

lista_zip = list(zip(country_list,year_list, value_list))

tabela = pd.DataFrame((lista_zip), columns=['country','year','value'])

display(tabela)
# Out:
#          country_name  year     value
# 0           Argentina  2020  20,767.6
# 1              Brazil  2020  14,836.3
# 2          Cabo Verde  2020   6,377.0
# 3            Colombia  2020  14,565.4
# 4    Egypt, Arab Rep.  2020  12,607.8
# ..                ...   ...       ...
# 200          Slovenia  2020       9.9
# 201            Brazil  2020        32
# 202           Germany  2020        82
# 203          Portugal  2020        75
# 204          Slovenia  2020       148
#
# [205 rows x 3 columns]

# %%
tabela.to_csv('tabela_dataworldbank_csv.csv', index=False)

# %% [raw]
# For link attempt

# %%
TED_link = "https://data.worldbank.org/indicator/SE.TER.ENRR?locations=BR-SI-DE-PT"
RD_link = "https://data.worldbank.org/indicator/GB.XPD.RSDV.GD.ZS?locations=BR-SI-DE-PT"
WPART_link ="https://data.worldbank.org/indicator/SL.TLF.CACT.FE.ZS?locations=BR-SI-DE-PT"
UN_link = "https://data.worldbank.org/indicator/SL.UEM.TOTL.ZS?locations=BR-SI-DE-PT"
FDI_link = "https://data.worldbank.org/indicator/BX.KLT.DINV.CD.WD?locations=BR-SI-DE-PT"
GDP_link = "https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.CD?locations=BR-SI-DE-PT"
GNI_link = "https://data.worldbank.org/indicator/SI.POV.GINI?locations=BR-SI-DE-PT"
DIR_link = "https://data.worldbank.org/indicator/FR.INR.DPST?locations=BR-SI-DE-PT"
TBLC_link = "https://data.worldbank.org/indicator/NE.RSB.GNFS.ZS?locations=BR-SI-DE-PT"
OPN_link = "https://data.worldbank.org/indicator/NE.TRD.GNFS.ZS?locations=BR-SI-DE-PT"

link_list = [TED_link, RD_link, WPART_link, UN_link, FDI_link, GDP_link, GNI_link, DIR_link, TBLC_link, OPN_link]
country_list =[]
year_list = {}
value_list = {}
navegador = webdriver.Chrome()

 
for link in link_list:
    navegador.get(link)
    country = navegador.find_element_by_xpath('//*[@id="mainChart"]/div/a/h1').text
    #country_list
    #country_list+str(link).append(country)
print(country_list+str(link))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-cf8d8c6f743d> in <module>
#      21     country = navegador.find_element_by_xpath('//*[@id="mainChart"]/div/a/h1').text
#      22     #country_list
# ---> 23     country_list+str(link).append(country)
#      24 print(country_list+str(link))
#
# AttributeError: 'str' object has no attribute 'append'

# %%
country_list_1 = ['france','argentine', 'portugal']
country_list = sorted(country_list_1)
print(country_list)
# Out:
# ['argentine', 'france', 'portugal']
